# %% [markdown]
# ## EC Notebook for Lecture 10:  Functions in Python
#
# This extra credit Python notebook will let you practice the material you saw in lecture.  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107! :)
#
# This notebook is worth +1 if turned in before 11:30am on **Friday, Sept. 20** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Importing pandas and reading data
# For this extra credit notebook, we will still use the Illinois GPA Distribution dataset -- as we did in lecture -- to do some exercise to get familiar with the function we learnt in the lecture
#
# You feel free to access the "GPA" dataset here: https://github.com/wadefagen/datasets/tree/master/gpa
# At first, you need to import the library pandas and reading the dataset.

# %%
import pandas as pd
df = pd.read_csv("gpa.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title  \
# 0      2018    Fall  2018-fa     AAS     100    Intro Asian American Studies
# 1      2018    Fall  2018-fa     AAS     100    Intro Asian American Studies
# 2      2018    Fall  2018-fa     AAS     100    Intro Asian American Studies
# 3      2018    Fall  2018-fa     AAS     100    Intro Asian American Studies
# 4      2018    Fall  2018-fa     AAS     100    Intro Asian American Studies
# 5      2018    Fall  2018-fa     AAS     105        Intro to Arab Am Studies
# 6      2018    Fall  2018-fa     AAS     211    Asian Americans and the Arts
# 7      2018    Fall  2018-fa     AAS     246    Asian American Youth in Film
# 8      2018    Fall  2018-fa     AAS     287        Food and Asian Americans
# 9      2018    Fall  2018-fa     ABE     100  Intro Agric & Biological Engrg
# 10     2018    Fall  2018-fa     ABE     223    ABE Principles: Machine Syst
# 11     2018    Fall  2018-fa     ABE     224    ABE Principles: Soil & Water
# 12     2018    Fall  2018-fa     ABE     430              Project Management
# 13     2018    Fall  2018-fa     ABE     436        Renewable Energy Systems
# 14     2018    Fall  2018-fa     ABE     466   Engineering Off-Road Vehicles
# 15     2018    Fall  2018-fa     ABE     488  Bioprocessing Biomass for Fuel
# 16     2018    Fall  2018-fa    ACCY     200      Fundamentals of Accounting
# 17     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 18     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 19     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 20     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 21     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 22     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 23     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 24     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 25     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 26     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 27     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 28     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# 29     2018    Fall  2018-fa    ACCY     201    Accounting and Accountancy I
# ...     ...     ...      ...     ...     ...                             ...
# 46515  2010  Summer  2010-su      PS     394                Crisis Diplomacy
# 46516  2010  Summer  2010-su    PSYC     201           Intro to Social Psych
# 46517  2010  Summer  2010-su    PSYC     201           Intro to Social Psych
# 46518  2010  Summer  2010-su    PSYC     224                 Cognitive Psych
# 46519  2010  Summer  2010-su    PSYC     230  Perception & Sensory Processes
# 46520  2010  Summer  2010-su    PSYC     363                   Dev Psych Lab
# 46521  2010  Summer  2010-su    RLST     110                 World Religions
# 46522  2010  Summer  2010-su     RST     100             Society and Leisure
# 46523  2010  Summer  2010-su    SCAN     251                Viking Mythology
# 46524  2010  Summer  2010-su     SHS     579   Prof/Eth/Legal Issues AuD/SLP
# 46525  2010  Summer  2010-su     SOC     200    Intro to Sociological Theory
# 46526  2010  Summer  2010-su     SOC     350          Technology and Society
# 46527  2010  Summer  2010-su     SOC     380         Social Research Methods
# 46528  2010  Summer  2010-su    SOCW     400  Generalist SW Practice Methods
# 46529  2010  Summer  2010-su    SOCW     400  Generalist SW Practice Methods
# 46530  2010  Summer  2010-su    SOCW     400  Generalist SW Practice Methods
# 46531  2010  Summer  2010-su    SOCW     410     Social Welfare Pol and Svcs
# 46532  2010  Summer  2010-su    SOCW     501         SW Practice with Groups
# 46533  2010  Summer  2010-su    SOCW     525   Supervision/Staff Development
# 46534  2010  Summer  2010-su    SOCW     531        Practice in Org Settings
# 46535  2010  Summer  2010-su    SOCW     531        Practice in Org Settings
# 46536  2010  Summer  2010-su    STAT     100                      Statistics
# 46537  2010  Summer  2010-su    STAT     100                      Statistics
# 46538  2010  Summer  2010-su    STAT     100                      Statistics
# 46539  2010  Summer  2010-su    STAT     400    Statistics and Probability I
# 46540  2010  Summer  2010-su    STAT     410   Statistics and Probability II
# 46541  2010  Summer  2010-su    STAT     440     Statistical Data Management
# 46542  2010  Summer  2010-su     TAM     212           Introductory Dynamics
# 46543  2010  Summer  2010-su     TAM     251    Introductory Solid Mechanics
# 46544  2010  Summer  2010-su     TAM     335    Introductory Fluid Mechanics
#
#        A+   A  A-  B+            ...              B-  C+   C  C-  D+  D  D-  \
# 0       2   8   8   7            ...               2   1   0   0   0  0   0
# 1       0  11   7   4            ...               2   0   0   0   0  0   0
# 2       1   6   7   4            ...               2   0   0   0   0  0   0
# 3       3   5   8   8            ...               1   0   1   1   1  0   0
# 4       0   6  12   2            ...               3   0   0   0   0  0   0
# 5      10   7   3   2            ...               0   0   1   0   0  1   0
# 6       2   6   5   1            ...               3   2   1   0   2  0   0
# 7       5  17   3   1            ...               0   1   0   1   0  0   0
# 8       3  25   0   2            ...               0   0   0   0   0  0   0
# 9       0  44   0   0            ...               0   0   2   0   0  0   0
# 10      0  17   4   6            ...               3   3   0   1   0  1   0
# 11      1  15  16   4            ...               0   0   1   0   1  0   0
# 12      9  88  10   0            ...               0   0   0   0   0  0   0
# 13      3   9   3  10            ...               3   4   1   1   0  0   0
# 14      2   8   3   1            ...               1   2   1   0   0  1   0
# 15      1  11   4   5            ...               1   0   2   0   0  0   0
# 16      8  83  44  30            ...              21  16  10   7   4  4   1
# 17      7   7   3   4            ...               2   0   2   1   0  0   0
# 18      5  10   2   6            ...               1   3   1   1   1  1   0
# 19      1   6   4   4            ...               4   2   1   4   4  0   0
# 20      5   3   4   9            ...               0   2   3   2   0  0   0
# 21      3   7   6   5            ...               4   2   3   1   2  0   1
# 22      1   5   6   4            ...               2   5   1   1   1  0   0
# 23      6  12   5   3            ...               2   1   2   1   0  0   0
# 24      4   5   2   2            ...               5   4   2   2   1  0   0
# 25      5   1   5   5            ...               2   1   4   2   1  0   0
# 26      2   7   6   6            ...               1   3   1   1   1  2   1
# 27      3   7   4   2            ...               5   3   2   2   0  1   0
# 28      5  10   3   1            ...               2   2   3   3   0  1   1
# 29      8   4   3   4            ...               3   1   2   2   0  0   0
# ...    ..  ..  ..  ..            ...              ..  ..  ..  ..  .. ..  ..
# 46515   0   5   1   3            ...               2   0   0   0   0  0   0
# 46516   8   9   2   3            ...               4   1   0   0   0  0   0
# 46517   5   7   3   3            ...               5   1   1   0   1  1   1
# 46518   4   2   5   3            ...               0   5   0   0   1  1   1
# 46519   9   8   1   1            ...               1   1   0   2   0  0   0
# 46520   1   9   1   1            ...               3   0   3   0   1  0   0
# 46521   0   9   4   4            ...               1   0   2   2   0  2   0
# 46522   0   7   1   7            ...               3   1   0   3   0  1   0
# 46523   1   4   7   5            ...               3   1   0   0   0  0   0
# 46524   0  16   6   8            ...               0   0   0   0   0  0   0
# 46525   2   5   4   3            ...               5   0   2   0   0  0   0
# 46526   1  25   0   0            ...               0   0   0   0   0  0   0
# 46527   1  12   4   5            ...               2   0   0   0   0  0   0
# 46528   0   6   6   5            ...               0   0   0   0   0  0   0
# 46529   4  12   8   1            ...               0   0   0   0   0  0   0
# 46530   0   7  12   2            ...               0   0   0   0   0  0   0
# 46531  14   8   2   3            ...               0   0   0   0   0  0   0
# 46532   0  15   4   1            ...               1   0   0   0   0  0   0
# 46533   0  11   7   6            ...               0   0   0   0   0  0   0
# 46534   0  20   0   0            ...               0   0   3   0   0  0   0
# 46535   0  23   0   0            ...               0   0   0   0   0  0   0
# 46536   5   4   0   1            ...               0   4   3   1   0  3   1
# 46537   1  13   3   3            ...               1   1   2   2   3  1   1
# 46538   0  14   3   1            ...               0   0   3   0   0  1   0
# 46539   4  15   7   2            ...               4   1   2   2   0  1   0
# 46540   5  10   2   2            ...               1   0   1   3   0  0   0
# 46541   4  12   8   1            ...               0   0   0   0   0  0   0
# 46542   0   1   3   2            ...               7   5   1   1   0  2   0
# 46543   1   2   2   1            ...               0   3   3   2   0  0   1
# 46544   5   8   9   4            ...               1   0   4   0   0  1   0
#
#        F  W         Primary Instructor
# 0      0  0            Thomas, Merin A
# 1      2  0                Lee, Sang S
# 2      2  0             Kang, Yoonjung
# 3      0  0            Thomas, Merin A
# 4      1  0                Lee, Sang S
# 5      0  0             Sharif, Lila A
# 6      2  0             Nguyen, Mimi T
# 7      0  1               Kwon, Soo Ah
# 8      0  0             Sharif, Lila A
# 9      0  0       Green-Miller, Angela
# 10     0  0              Grift, Tony E
# 11     0  0           Bhattarai, Rabin
# 12     0  0           Davidson, Paul C
# 13     0  0               Wang, Xinlei
# 14     0  0             Hansen, Alan C
# 15     0  0               Singh, Vijay
# 16     1  1            Silhan, Peter A
# 17     0  1         Fisher, Mitchell B
# 18     0  1         Fisher, Mitchell B
# 19     0  0         Fisher, Mitchell B
# 20     1  1         Fisher, Mitchell B
# 21     0  0         Fisher, Mitchell B
# 22     2  1         Fisher, Mitchell B
# 23     0  0         Fisher, Mitchell B
# 24     2  0         Fisher, Mitchell B
# 25     0  1         Fisher, Mitchell B
# 26     0  0         Fisher, Mitchell B
# 27     2  0         Fisher, Mitchell B
# 28     1  0         Fisher, Mitchell B
# 29     2  0         Fisher, Mitchell B
# ...   .. ..                        ...
# 46515  1  0            Vasquez, John A
# 46516  0  0             Ritter, Ryan S
# 46517  0  0                   Su, Rong
# 46518  2  1        Kittredge, Audrey K
# 46519  0  0             Higgins, James
# 46520  2  0             Elieff, Chryle
# 46521  0  0              Evers, John R
# 46522  1  0           Davitt, Brooke N
# 46523  0  0       Schwink, Frederick W
# 46524  0  0       Echols-Chambers, Lou
# 46525  0  0         Barnett, Bernice M
# 46526  1  0        Shoffstall, Grant W
# 46527  1  0            Niehans, Keri M
# 46528  0  0                Bragg, Mary
# 46529  0  0            Johnson, Jill L
# 46530  0  0  Hampton-Campbel, Sharva Y
# 46531  0  0     Hack-Ritzo, Samantha M
# 46532  0  0          Lindsey, Brenda C
# 46533  0  0               Ward, Thomas
# 46534  0  0      Wilson Smith, Carol J
# 46535  0  0         Fessler, Sherrie M
# 46536  0  1       Bawawana, Bavwidinsi
# 46537  1  0         Hirtz, Nathaniel R
# 46538  3  1           Dalpiaz, David M
# 46539  3  1             Monrad, Ditlev
# 46540  2  1         Stepanov, Alexei G
# 46541  0  0               Unger, David
# 46542  1  0          Morgan, William T
# 46543  1  0   Ott-Monsivais, Stephanie
# 46544  2  0           Keane, Richard D
#
# [46545 rows x 21 columns]

# %% [markdown]
# ## 2. Review: Group Function
# The Student Union at Illinois would like to investiage the grading policy for the university courses and subjects， especailly for "ACCY", "CS", "MATH", "STAT".
#
# ### Question 1:
# Using the GPA dataset, you need to calculate the proportion of ("A+","A") in ("A+","A","A-","B+","B","B-") for subjects "ACCY", "CS", "MATH", "STAT", respectively. Hint: use the groupby function.

# %%
df_subj = df[(df["Subject"] == "CS") | (df["Subject"] == "ACCY") | (df["Subject"] == "MATH") | (df["Subject"] == "STAT")]
group = df_subj.groupby("Subject")
df_group = group.agg("sum").reset_index()
df_group
ratio = (df_group["A+"] + df_group["A"]) / (df_group["A+"] + df_group["A"] + df_group["B+"] + df_group["B-"] + df_group["B"] + df_group["A-"])
print(ratio[1])
# Out:
# 0.4851959027145017

# %%
## == TEST CASES for Question 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(ratio[1] == 0.4851959027145017), "The ratio for the ACCY does not appear correct."

# %% [markdown]
# ## 3. Review: Group Function
# Besides the raito of ("A+","A") in ("A+","A","A-","B+","B","B-"), the student union also wants to know the difference between the largest number of "A+" and the largest number of "A" in each subject, and what is the largest gap among all subjects.
#
# ### Question 2:
# Using the GPA dataset, you need to find the difference between the largest number of "A+" and the largest number of"A" for each subject firstly, and then based on what you have, to calculate the largest gap among all subjects.

# %%
df_group_max = group.agg("max").reset_index()

gap = df_group_max["A+"] - df_group_max["A"]
print(gap_largest)
# Out:
# 50

# %%
## == TEST CASES for Question 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(gap_largest == 481), "The number does not appear correct."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-cb0a68c4f845> in <module>
#       4 # - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
#       5
# ----> 6 assert(gap_largest == 481), "The number does not appear correct."
#
# AssertionError: The number does not appear correct.

# %% [markdown]
# ## 4. Review: Group Function
# In addition, the student union also wants to know hom many subjects which the instructors give "A" but not "A+".
#
#
# ### Question 3:
# Using the GPA dataset, we have defined a function to give the label (column "course_type") for those course which the instructors give "A" but not "A+". For your work, you need to decide how many subjects which the instructors give "A" but not "A+". Hint: The question is asking about each subject not each course, so you also need to use groupby function.

# %%
## Just Run the following code. 
def course(x):

   if x["A+"] == 0 and x["A"] > 0 : return 1

   else: return 0
    
df["course_type"] = df.apply(course, axis=1)
## Just Run the above code. 

num = ...
print(num)

# %%
## == TEST CASES for Question 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(num == 13), "The number of this type of course does not appear correct."
