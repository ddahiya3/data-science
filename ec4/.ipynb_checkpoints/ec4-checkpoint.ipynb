# %% [markdown]
# # EC Notebook for Lecture 4: Blocking and Conditionals
#
# This extra credit Python notebook will let you practice the material you saw in lecture!  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107!
#
# This notebook is worth +1 if turned in before 11:30am on **Friday, Sept. 6** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will continue to use the "Hello" dataset introduced last lecture!
#
# Using your @illinois.edu address, download the dataset as a CSV and **make sure to save or move it to the same directory as this notebook**: https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0
#
# Use the following cell to load the pandas library and read the DataSet as a DataFrame:

# %%
import pandas as pd
df = pd.read_csv("HelloDataset.csv")

# %% [markdown]
# ## 2. Finising the Lecture Problem
#
# In lecture, we left you with a final puzzle.  From the lecture handout:
#
# > Use Python to create a control group of 20 students, using blocking to control for the influence we suspect having more than 1 siblings might have.  Make sure you have an equal number of students with 0 or 1 sibling and an equal number of students with 2 or more siblings.
#
# We will complete this in four separate steps to get practice on each part.
#
# #### 2.1: Sibling Block #1
#
# Creating a DataFrame that contains all students with 0 or 1 siblings and call it `block1`:

# %%
block1 = df[df["Siblings"] <= 1]
block1
# Out:
#          Name                           Major School Year     Type  \
# 2        noor       global studies/statistics   Sophomore   iPhone
# 3    Jonathan               Political Science      Senior   iPhone
# 4       Clare                      Statistics   Sophomore   iPhone
# 7       Margo                       Chemistry      Senior   iPhone
# 8     Natalia                      Psychology    Freshman   iPhone
# ..        ...                             ...         ...      ...
# 155    Serena                            Math      Senior   iPhone
# 158       Ash  Consumer Economics and Finance      Junior   iPhone
# 162     Cindy          biomedical engineering      Senior  Android
# 164      John          Statistics or Business    Freshman   iPhone
# 165    Anisha                             Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# 7    Mac OS X-based computer          0.5         1         0         0
# 8                      Other          1.0         0         0         0
# ..                       ...          ...       ...       ...       ...
# 155  Mac OS X-based computer          2.0         0         1         0
# 158  Mac OS X-based computer          1.0         0         0         0
# 162   Windows-based computer          1.0         1         0         0
# 164   Windows-based computer          1.0         1         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# 7               0  ...           0                  No
# 8               0  ...           0                  No
# ..            ...  ...         ...                 ...
# 155             0  ...           0                 Yes
# 158             0  ...           0                 Yes
# 162             0  ...           0                  No
# 164             0  ...           1                  No
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# 7    No programming background -- is Python Taylor ...                   0
# 8    No programming background -- is Python Taylor ...                   1
# ..                                                 ...                 ...
# 155  Some Python -- I have had one class or written...                   4
# 158  Some Python -- I have had one class or written...                   4
# 162  No Python, but I've done some programming in o...                   1
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# 7              5.0       1.0             8.0          8.0
# 8              4.0       1.0             7.0          5.0
# ..             ...       ...             ...          ...
# 155            4.0       0.0             7.0         15.0
# 158            3.0       1.0             6.0         20.0
# 162            2.0       1.0             8.0          3.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# 7                       20.0     Ambivert
# 8                        4.0     Ambivert
# ..                       ...          ...
# 155                      5.0     Ambivert
# 158                     10.0     Ambivert
# 162                      8.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [100 rows x 31 columns]

# %% [markdown]
# #### 2.2: Sibling Block #2
#
# Create a DataFrame that contains all students with 2 or more siblings and call it `block2`:

# %%
block2 = df[df["Siblings"] >= 2]
block2
# Out:
#            Name                        Major School Year     Type  \
# 0          Wade             Computer Science       Other  Android
# 1         Karle                   Statistics       Other   iPhone
# 5         Dhruv             Computer science   Sophomore  Android
# 6          Alex                      Physics      Junior  Android
# 9    Edward/Edd  CS, business data analysis?      Senior  Android
# ..          ...                          ...         ...      ...
# 157       Donny         Information Sciences      Junior   iPhone
# 159      Julisa                  Mathematics   Sophomore   iPhone
# 160        Nate                   Statistics   Sophomore   iPhone
# 161   Stephanie            Political Science      Junior   iPhone
# 163       Talal         Information sciences   Sophomore   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 5     Windows-based computer          1.0         0         0         0
# 6     Windows-based computer          1.0         0         0         0
# 9       Linux-based computer          1.0         0         0         0
# ..                       ...          ...       ...       ...       ...
# 157   Windows-based computer          1.0         0         0         0
# 159   Windows-based computer          2.0         0         0         0
# 160   Windows-based computer          1.0         1         0         0
# 161  Mac OS X-based computer          NaN         1         0         0
# 163   Windows-based computer          1.0         0         1         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 5               0  ...           1                 Yes
# 6               0  ...           0                 Yes
# 9               0  ...           1                 Yes
# ..            ...  ...         ...                 ...
# 157             0  ...           0                  No
# 159             0  ...           0                 Yes
# 160             0  ...           1                 Yes
# 161             0  ...           0                  No
# 163             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 5    Some Python -- I have had one class or written...                   0
# 6    Some Python -- I have had one class or written...                   1
# 9    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 157  No Python, but I've done some programming in o...                   1
# 159  Some Python -- I have had one class or written...                   0
# 160  No Python, but I've done some programming in o...                   1
# 161  No programming background -- is Python Taylor ...                   1
# 163  No Python, but I've done some programming in o...                   0
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 5              3.0       2.0             6.0          4.0
# 6              0.0       2.0             6.0          2.0
# 9              3.0       2.0             8.0          5.0
# ..             ...       ...             ...          ...
# 157            2.0       2.0             7.0          3.0
# 159            3.0       3.0             5.0         10.0
# 160            8.0       4.0             8.0         12.0
# 161            2.0       9.0             7.0         30.0
# 163            3.0       2.0             8.0         12.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 5                       11.0    Introvert
# 6                       74.0    Introvert
# 9                       10.0     Ambivert
# ..                       ...          ...
# 157                     20.0     Ambivert
# 159                     15.0    Extrovert
# 160                    100.0     Ambivert
# 161                     12.0    Extrovert
# 163                     25.0     Ambivert
#
# [65 rows x 31 columns]

# %% [markdown]
# #### 2.3: Selecting equal groups from block1 and block2
#
# **Randomly** select an equal number of students from each of `block1` and `block2` and store them in `control1` and `control2`.  We will combine both groups to make the full control group:

# %%
control1 = block1.sample(n=10)
control1
# Out:
#           Name                                              Major School Year  \
# 102    Bradley           Computer science and applied mathematics    Freshman
# 90     Stephen                      Psychology & Computer Science    Freshman
# 70         Jie                                            Biology    Freshman
# 141       Andi  Computer Science + Statistics or Statistics ma...   Sophomore
# 79   Tanushree                                          Astronomy    Freshman
# 153         LJ                                                NaN    Freshman
# 121    Gerardo                                           Business    Freshman
# 73    Caroline                             Industrial Engineering       Other
# 91       Angel                                   Computer Science   Sophomore
# 2         noor                          global studies/statistics   Sophomore
#
#         Type                 Computer  Straw Holes  Has Dogs  Has Cats  \
# 102   iPhone  Mac OS X-based computer          1.0         0         1
# 90   Android  Mac OS X-based computer          2.0         1         1
# 70    iPhone  Mac OS X-based computer          1.0         1         0
# 141   iPhone   Windows-based computer          1.0         1         0
# 79    iPhone  Mac OS X-based computer          1.0         0         0
# 153  Android   Windows-based computer          1.0         0         1
# 121   iPhone   Windows-based computer          1.0         0         0
# 73    iPhone   Windows-based computer          2.0         1         0
# 91    iPhone   Windows-based computer          2.0         0         1
# 2     iPhone  Mac OS X-based computer          1.0         0         0
#
#      Has Fish  Has Chickens  ...  Has Twitch  Programmed before?  \
# 102         0             0  ...           0                 Yes
# 90          0             0  ...           1                 Yes
# 70          0             0  ...           0                  No
# 141         0             0  ...           1                 Yes
# 79          0             0  ...           0                  No
# 153         0             0  ...           0                  No
# 121         0             0  ...           0                 Yes
# 73          0             0  ...           0                 Yes
# 91          0             0  ...           0                 Yes
# 2           0             0  ...           0                  No
#
#                                      Python Background  Statistics Courses  \
# 102  Some Python -- I have had one class or written...                   0
# 90   Some Python -- I have had one class or written...                   0
# 70   No programming background -- is Python Taylor ...                   1
# 141  Some Python -- I have had one class or written...                   2
# 79   No programming background -- is Python Taylor ...                   0
# 153  No programming background -- is Python Taylor ...                   0
# 121  No Python, but I've done some programming in o...                   0
# 73   No Python, but I've done some programming in o...                   2
# 91   Some Python -- I have had one class or written...                   1
# 2    No programming background -- is Python Taylor ...                   3
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 102            4.0       1.0             7.0          4.0
# 90            10.0       0.0             7.5          2.0
# 70             3.0       1.0             7.0          5.0
# 141            1.0       1.0             6.0          3.0
# 79             6.0       1.0             5.0         25.0
# 153            6.0       0.0             7.0          3.0
# 121            0.0       0.0             9.0          5.0
# 73             3.0       0.0             8.0         14.0
# 91             5.0       1.0             5.0          4.0
# 2              3.0       1.0             7.0         20.0
#
#      People Texted Yesterday  Personality
# 102                     10.0     Ambivert
# 90                       8.0    Introvert
# 70                       NaN     Ambivert
# 141                     10.0    Introvert
# 79                      15.0    Introvert
# 153                      8.0    Extrovert
# 121                     20.0    Extrovert
# 73                       8.0     Ambivert
# 91                       8.0    Introvert
# 2                       10.0    Introvert
#
# [10 rows x 31 columns]

# %%
control2 = block2.sample(n=10)
control2
# Out:
#          Name                            Major School Year     Type  \
# 126   Jaesung                        Economics      Senior   iPhone
# 16    Natasha  Computer Science and Philosophy    Freshman   iPhone
# 54   Saharish                Political Science      Senior   iPhone
# 14       Gail                      Art History      Senior  Android
# 81       Rami                       Psychology    Freshman  Android
# 20       Matt                             Math      Junior   iPhone
# 66     Ikenna                 Computer science      Junior   iPhone
# 85      Olive                  Theatre Studies    Freshman   iPhone
# 112   Enrique                 Computer Science      Senior   iPhone
# 159    Julisa                      Mathematics   Sophomore   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 126  Mac OS X-based computer          1.0         0         0         0
# 16   Mac OS X-based computer          1.0         0         0         0
# 54   Mac OS X-based computer          1.0         1         0         0
# 14    Windows-based computer          1.0         1         0         0
# 81   Mac OS X-based computer          2.0         0         0         0
# 20   Mac OS X-based computer          1.0         0         1         0
# 66    Windows-based computer          1.0         0         0         0
# 85                     Other          1.0         1         1         0
# 112  Mac OS X-based computer          1.0         1         0         0
# 159   Windows-based computer          2.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 126             0  ...           1                 Yes
# 16              0  ...           0                 Yes
# 54              0  ...           0                  No
# 14              0  ...           0                 Yes
# 81              0  ...           0                  No
# 20              0  ...           0                 Yes
# 66              0  ...           0                 Yes
# 85              0  ...           0                  No
# 112             0  ...           0                 Yes
# 159             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 126  No Python, but I've done some programming in o...                   3
# 16   No Python, but I've done some programming in o...                   1
# 54   No programming background -- is Python Taylor ...                   1
# 14   No Python, but I've done some programming in o...                   2
# 81   No programming background -- is Python Taylor ...                   1
# 20   Significant -- I am a wizard when it comes to ...                   0
# 66   No Python, but I've done some programming in o...                   2
# 85   No programming background -- is Python Taylor ...                   1
# 112  Some Python -- I have had one class or written...                   2
# 159  Some Python -- I have had one class or written...                   0
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 126           12.0       2.0             7.0          5.0
# 16             6.0       2.0             7.0         12.0
# 54             5.0       2.0             6.5         10.0
# 14             3.0       2.0             7.0          8.0
# 81             4.0       2.0             6.0          5.0
# 20             3.0       2.0             8.0          2.0
# 66             3.0       8.0             9.0         13.0
# 85             2.0       3.0             7.0          8.0
# 112            3.0       3.0             7.0         12.0
# 159            3.0       3.0             5.0         10.0
#
#      People Texted Yesterday  Personality
# 126                      3.0    Introvert
# 16                      50.0    Extrovert
# 54                      17.0     Ambivert
# 14                       2.0    Introvert
# 81                       6.0     Ambivert
# 20                      10.0     Ambivert
# 66                      11.0     Ambivert
# 85                       5.0     Ambivert
# 112                      6.0     Ambivert
# 159                     15.0    Extrovert
#
# [10 rows x 31 columns]

# %% [markdown]
# #### 2.4. Combine the two sub-groups into a single control group
#
# Use the following code to merge the contents of `control1` and `control2` together into one large group called `control`:

# %%
control = control1.append(control2)
control
# Out:
#           Name                                              Major School Year  \
# 102    Bradley           Computer science and applied mathematics    Freshman
# 90     Stephen                      Psychology & Computer Science    Freshman
# 70         Jie                                            Biology    Freshman
# 141       Andi  Computer Science + Statistics or Statistics ma...   Sophomore
# 79   Tanushree                                          Astronomy    Freshman
# 153         LJ                                                NaN    Freshman
# 121    Gerardo                                           Business    Freshman
# 73    Caroline                             Industrial Engineering       Other
# 91       Angel                                   Computer Science   Sophomore
# 2         noor                          global studies/statistics   Sophomore
# 126    Jaesung                                          Economics      Senior
# 16     Natasha                    Computer Science and Philosophy    Freshman
# 54    Saharish                                  Political Science      Senior
# 14        Gail                                        Art History      Senior
# 81        Rami                                         Psychology    Freshman
# 20        Matt                                               Math      Junior
# 66      Ikenna                                   Computer science      Junior
# 85       Olive                                    Theatre Studies    Freshman
# 112    Enrique                                   Computer Science      Senior
# 159     Julisa                                        Mathematics   Sophomore
#
#         Type                 Computer  Straw Holes  Has Dogs  Has Cats  \
# 102   iPhone  Mac OS X-based computer          1.0         0         1
# 90   Android  Mac OS X-based computer          2.0         1         1
# 70    iPhone  Mac OS X-based computer          1.0         1         0
# 141   iPhone   Windows-based computer          1.0         1         0
# 79    iPhone  Mac OS X-based computer          1.0         0         0
# 153  Android   Windows-based computer          1.0         0         1
# 121   iPhone   Windows-based computer          1.0         0         0
# 73    iPhone   Windows-based computer          2.0         1         0
# 91    iPhone   Windows-based computer          2.0         0         1
# 2     iPhone  Mac OS X-based computer          1.0         0         0
# 126   iPhone  Mac OS X-based computer          1.0         0         0
# 16    iPhone  Mac OS X-based computer          1.0         0         0
# 54    iPhone  Mac OS X-based computer          1.0         1         0
# 14   Android   Windows-based computer          1.0         1         0
# 81   Android  Mac OS X-based computer          2.0         0         0
# 20    iPhone  Mac OS X-based computer          1.0         0         1
# 66    iPhone   Windows-based computer          1.0         0         0
# 85    iPhone                    Other          1.0         1         1
# 112   iPhone  Mac OS X-based computer          1.0         1         0
# 159   iPhone   Windows-based computer          2.0         0         0
#
#      Has Fish  Has Chickens  ...  Has Twitch  Programmed before?  \
# 102         0             0  ...           0                 Yes
# 90          0             0  ...           1                 Yes
# 70          0             0  ...           0                  No
# 141         0             0  ...           1                 Yes
# 79          0             0  ...           0                  No
# 153         0             0  ...           0                  No
# 121         0             0  ...           0                 Yes
# 73          0             0  ...           0                 Yes
# 91          0             0  ...           0                 Yes
# 2           0             0  ...           0                  No
# 126         0             0  ...           1                 Yes
# 16          0             0  ...           0                 Yes
# 54          0             0  ...           0                  No
# 14          0             0  ...           0                 Yes
# 81          0             0  ...           0                  No
# 20          0             0  ...           0                 Yes
# 66          0             0  ...           0                 Yes
# 85          0             0  ...           0                  No
# 112         0             0  ...           0                 Yes
# 159         0             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 102  Some Python -- I have had one class or written...                   0
# 90   Some Python -- I have had one class or written...                   0
# 70   No programming background -- is Python Taylor ...                   1
# 141  Some Python -- I have had one class or written...                   2
# 79   No programming background -- is Python Taylor ...                   0
# 153  No programming background -- is Python Taylor ...                   0
# 121  No Python, but I've done some programming in o...                   0
# 73   No Python, but I've done some programming in o...                   2
# 91   Some Python -- I have had one class or written...                   1
# 2    No programming background -- is Python Taylor ...                   3
# 126  No Python, but I've done some programming in o...                   3
# 16   No Python, but I've done some programming in o...                   1
# 54   No programming background -- is Python Taylor ...                   1
# 14   No Python, but I've done some programming in o...                   2
# 81   No programming background -- is Python Taylor ...                   1
# 20   Significant -- I am a wizard when it comes to ...                   0
# 66   No Python, but I've done some programming in o...                   2
# 85   No programming background -- is Python Taylor ...                   1
# 112  Some Python -- I have had one class or written...                   2
# 159  Some Python -- I have had one class or written...                   0
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 102            4.0       1.0             7.0          4.0
# 90            10.0       0.0             7.5          2.0
# 70             3.0       1.0             7.0          5.0
# 141            1.0       1.0             6.0          3.0
# 79             6.0       1.0             5.0         25.0
# 153            6.0       0.0             7.0          3.0
# 121            0.0       0.0             9.0          5.0
# 73             3.0       0.0             8.0         14.0
# 91             5.0       1.0             5.0          4.0
# 2              3.0       1.0             7.0         20.0
# 126           12.0       2.0             7.0          5.0
# 16             6.0       2.0             7.0         12.0
# 54             5.0       2.0             6.5         10.0
# 14             3.0       2.0             7.0          8.0
# 81             4.0       2.0             6.0          5.0
# 20             3.0       2.0             8.0          2.0
# 66             3.0       8.0             9.0         13.0
# 85             2.0       3.0             7.0          8.0
# 112            3.0       3.0             7.0         12.0
# 159            3.0       3.0             5.0         10.0
#
#      People Texted Yesterday  Personality
# 102                     10.0     Ambivert
# 90                       8.0    Introvert
# 70                       NaN     Ambivert
# 141                     10.0    Introvert
# 79                      15.0    Introvert
# 153                      8.0    Extrovert
# 121                     20.0    Extrovert
# 73                       8.0     Ambivert
# 91                       8.0    Introvert
# 2                       10.0    Introvert
# 126                      3.0    Introvert
# 16                      50.0    Extrovert
# 54                      17.0     Ambivert
# 14                       2.0    Introvert
# 81                       6.0     Ambivert
# 20                      10.0     Ambivert
# 66                      11.0     Ambivert
# 85                       5.0     Ambivert
# 112                      6.0     Ambivert
# 159                     15.0    Extrovert
#
# [20 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(control) == 20 ), "Your control group must only have 20 courses in it."
assert( len(control[control.Siblings < 2] ) == 10 ), "Your control group must only have 10 people with 0-1 siblings in it."
assert( len(control[control.Siblings >= 2] ) == 10 ), "Your control group must only have 10 people with 2+ siblings in it."

# %% [markdown]
# ## 3. Create a treatment group
#
# Let's extend what you did onto a new topic.  Using this week's dataset, the course catalog at Illinois, use Python to create a treatment group of 10 courses, using blocking to control for the influence we suspect being an upper-level course might have.
#
# An upper-level course is a course that has a number course number of 300 or higher.  Make sure you have an equal number of lower-level and upper-level courses in your final treatment group.
#
# You can find the course catalog dataset here: https://docs.google.com/spreadsheets/d/1ZnpZpipyui_zIIBblmalRYiyEG1glUKinqJtQxVL04o/edit#gid=0
#
# You have several cells to work in if you need them.  The only requirement is that your final treatment group must be randomly selected and be stored in the variable `treatment`.

# %%
import pandas as pd
df2 = pd.read_csv("coursecatalog.csv")

block_upper = df2[df2["Number"] >= 300]
block_lower = df2[df2["Number"] < 300]

treatment_upper = block_upper.sample(n=5)
treatment_lower = block_lower.sample(n=5)

# %%
# Make sure your final answer is in `treatment`:
treatment = treatment_upper.append(treatment_lower)
treatment
# Out:
#       Year  Term YearTerm Subject  Number  \
# 7606  2019  Fall  2019-fa     SHS     333
# 6263  2019  Fall  2019-fa     MUS     434
# 83    2019  Fall  2019-fa     ABE     501
# 3050  2019  Fall  2019-fa    ECON     543
# 8279  2019  Fall  2019-fa    THEA     559
# 5217  2019  Fall  2019-fa     LAS     122
# 517   2019  Fall  2019-fa    AGCM     270
# 1806  2019  Fall  2019-fa    CHBE     221
# 3712  2019  Fall  2019-fa      FR     195
# 5475  2019  Fall  2019-fa     LLS     200
#
#                                                    Name  \
# 7606  Children with Neurodevelopmental Disorders Acr...
# 6263       Assessment and Evaluation in Music Education
# 83                                  Graduate Research I
# 3050                       Workplace Dispute Resolution
# 8279                         Topics in Stage Management
# 5217                             Leadership and Society
# 517               Ag Sales and Persuasive Communication
# 1806                                  Principles of CHE
# 3712                      French Intellectual Tradition
# 5475                               U.S. Race and Empire
#
#                                             Description   Credit Hours  \
# 7606  This course introduces students to the develop...       3 hours.
# 6263  Overview of assessment and evaluation techniqu...  3 OR 4 hours.
# 83    Basic research orientation, research methods, ...       1 hours.
# 3050          Same as LAW 665 and LER 543. See LER 543.  3 OR 4 hours.
# 8279  This course surveys advanced topics in stage m...       2 hours.
# 5217  Engages first-year LAS honors students in the ...       1 hours.
# 517   Sales concepts and persuasive business communi...       3 hours.
# 1806  Lectures and problems on material and energy b...       3 hours.
# 3712  Close reading and in-depth discussion of texts...       3 hours.
# 5475                      Same as AAS 200. See AAS 200.       3 hours.
#
#                                            Section Info  \
# 7606                                                NaN
# 6263                                                NaN
# 83                                                  NaN
# 3050          Same as LAW 665 and LER 543. See LER 543.
# 8279  2 graduate hours. No professional credit. May ...
# 5217                                                NaN
# 517                                                 NaN
# 1806  Prerequisite: CHEM 104 or CHEM 204; credit or ...
# 3712                                                NaN
# 5475                      Same as AAS 200. See AAS 200.
#
#                                       Degree Attributes
# 7606                                                NaN
# 6263                                                NaN
# 83                                                  NaN
# 3050                                                NaN
# 8279                                                NaN
# 5217                             James Scholars course.
# 517                                                 NaN
# 1806                                                NaN
# 3712                   Humanities - Hist & Phil course.
# 5475  Humanities - Hist & Phil, and Cultural Studies...

# %%
## == TEST CASES for Puzzle 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(treatment) == 10 ), "Your treatment group must only have 10 courses in it."
assert( len(treatment[treatment.Number < 300] ) == 5 ), "Your treatment group must only have 5 lower-level courses in it."
assert( len(treatment[treatment.Number >= 300] ) == 5 ), "Your treatment group must only have 5 upper-level courses in it."

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
