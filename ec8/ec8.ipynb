# %% [markdown]
# # EC Notebook for Lecture 7: Working with columns
#
# This extra credit Python notebook will let you practice the material you saw in lecture.  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107! :)
#
# This notebook is worth +1 if turned in before 11:30am on **Friday, Sept. 13** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will use the "Hello" dataset -- as we did in lecture -- to answer a few questions on working with columns.
#
# Using your @illinois.edu address, you can access the "Hello" dataset here: https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0

# %%
import pandas as pd
df = pd.read_csv("hello.csv")

# %% [markdown]
# ## 2. Spread of sleeping hours among Freshmen
# After coming to college, some people start burning the midnight oil from the very first day and hence sleep less. At the same time, there are few people who are still tired because of the celeberation they had after graduating from high school and hence sleep more. Let's find out what is the average and the spread of sleeping hours among freshmen in our class.
#
# ### Question 1:
# Using the "hello.csv" dataset, calculate the mean and the standard deviation (std) in number of hours of sleep among freshmen.
# (Please note that "std" is a common abbreviation for standard deviation.)

# %%
df_freshman = df[df["School Year"] == "Freshman"]
freshmen_sleep_mean = df_freshman["Hours of Sleep"].mean()
freshmen_sleep_std = df_freshman["Hours of Sleep"].std()
print(freshmen_sleep_mean)
print(freshmen_sleep_std)
df_freshman
# Out:
# 7.09
# 0.8124666398174919
#           Name                                     Major School Year     Type  \
# 8      Natalia                                Psychology    Freshman   iPhone
# 10       Taige                                 Math + CS    Freshman   iPhone
# 16     Natasha           Computer Science and Philosophy    Freshman   iPhone
# 17       Yijie              Computer Science+Mathematics    Freshman  Android
# 18      steven                              data science    Freshman  Android
# 21       Colin                         Actuarial Science    Freshman   iPhone
# 23       Yosup            Computer Science + Mathematics    Freshman  Android
# 25    Caroline                                   Finance    Freshman   iPhone
# 26        Eric                              Not sure yet    Freshman   iPhone
# 29      Eugene             Statistics + Computer Science    Freshman   iPhone
# 32         Uma            Molecular and Cellular Biology    Freshman   iPhone
# 33        Nick                         Political Science    Freshman  Android
# 35        Niks          Mathematics and Computer Science    Freshman  Android
# 37        Jose                         Political Science    Freshman  Android
# 41     Michael                          Computer Science    Freshman   iPhone
# 43       Louie                            CS + Astronomy    Freshman   iPhone
# 45         Leo                                       CS?    Freshman   iPhone
# 51    Zhoutian                      Computer Engineering    Freshman   iPhone
# 61       Tyler                         actuarial science    Freshman  Android
# 62       Boyou                               Mathematics    Freshman  Android
# 68     Amartya                              Astrophysics    Freshman  Android
# 70         Jie                                   Biology    Freshman   iPhone
# 72        Isha                                Psychology    Freshman   iPhone
# 74      Alexus                          Computer Science    Freshman   iPhone
# 78        Andy                          Computer Science    Freshman   iPhone
# 79   Tanushree                                 Astronomy    Freshman   iPhone
# 81        Rami                                Psychology    Freshman  Android
# 82        Tian                             data analysis    Freshman   iPhone
# 84         Mit                                   Physics    Freshman  Android
# 85       Olive                           Theatre Studies    Freshman   iPhone
# 90     Stephen             Psychology & Computer Science    Freshman  Android
# 92        Yena                               Mathematics    Freshman   iPhone
# 94      Xavier                            Global Studies    Freshman   iPhone
# 95      Nicole                         Political Science    Freshman   iPhone
# 97       Oscar                 Engineering CS or Math&CS    Freshman   iPhone
# 102    Bradley  Computer science and applied mathematics    Freshman   iPhone
# 105      katie       political science and maybe Cs+econ    Freshman   iPhone
# 106     Victor                      Finacial Engineering    Freshman   iPhone
# 110       Amey                          Computer Science    Freshman   iPhone
# 111      David                                Psychology    Freshman   iPhone
# 113       Alex                  Media and Cinema Studies    Freshman   iPhone
# 118      Mendy                         Political Science    Freshman   iPhone
# 119        You                          Computer science    Freshman   iPhone
# 120     Sumedh           Statistics and Computer Science    Freshman  Android
# 121    Gerardo                                  Business    Freshman   iPhone
# 134      Roman                          Computer Science    Freshman   iPhone
# 140    Makayla                  Media and Cinema Studies    Freshman   iPhone
# 151        Jun                                     maths    Freshman   iPhone
# 153         LJ                                       NaN    Freshman  Android
# 164       John                    Statistics or Business    Freshman   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 8                      Other          1.0         0         0         0
# 10    Windows-based computer          1.0         0         1         0
# 16   Mac OS X-based computer          1.0         0         0         0
# 17   Mac OS X-based computer          2.0         0         0         0
# 18    Windows-based computer          2.0         0         0         1
# 21    Windows-based computer          1.0         1         0         0
# 23   Mac OS X-based computer          2.0         0         0         0
# 25   Mac OS X-based computer          1.0         1         0         0
# 26   Mac OS X-based computer          1.0         0         0         0
# 29   Mac OS X-based computer          2.0         0         0         0
# 32   Mac OS X-based computer          1.0         0         0         0
# 33    Windows-based computer          1.0         1         1         0
# 35    Windows-based computer          2.0         0         0         0
# 37                     Other          1.0         1         1         0
# 41   Mac OS X-based computer          4.0         1         0         0
# 43   Mac OS X-based computer          2.0         1         1         0
# 45    Windows-based computer          1.0         0         0         1
# 51    Windows-based computer          1.0         0         0         1
# 61    Windows-based computer          1.0         1         1         0
# 62    Windows-based computer          1.0         0         0         0
# 68    Windows-based computer          1.0         0         0         0
# 70   Mac OS X-based computer          1.0         1         0         0
# 72    Windows-based computer          2.0         1         0         0
# 74    Windows-based computer          1.0         1         0         0
# 78    Windows-based computer          1.0         1         0         0
# 79   Mac OS X-based computer          1.0         0         0         0
# 81   Mac OS X-based computer          2.0         0         0         0
# 82   Mac OS X-based computer          1.0         1         0         0
# 84   Mac OS X-based computer          1.0         1         0         0
# 85                     Other          1.0         1         1         0
# 90   Mac OS X-based computer          2.0         1         1         0
# 92   Mac OS X-based computer          1.0         1         0         0
# 94    Windows-based computer          2.0         1         0         0
# 95   Mac OS X-based computer          1.0         0         1         0
# 97    Windows-based computer          1.0         0         0         0
# 102  Mac OS X-based computer          1.0         0         1         0
# 105   Windows-based computer          1.0         1         0         1
# 106   Windows-based computer          1.0         0         0         0
# 110  Mac OS X-based computer          1.0         0         0         1
# 111  Mac OS X-based computer          2.0         1         0         0
# 113   Windows-based computer          2.0         1         0         0
# 118  Mac OS X-based computer          1.0         0         0         1
# 119  Mac OS X-based computer          2.0         1         0         0
# 120   Windows-based computer          2.0         0         0         0
# 121   Windows-based computer          1.0         0         0         0
# 134  Mac OS X-based computer          1.0         0         0         0
# 140                    Other          2.0         1         0         0
# 151  Mac OS X-based computer          1.0         0         0         0
# 153   Windows-based computer          1.0         0         1         0
# 164   Windows-based computer          1.0         1         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 8               0  ...           0                  No
# 10              0  ...           1                 Yes
# 16              0  ...           0                 Yes
# 17              0  ...           0                 Yes
# 18              0  ...           0                 Yes
# 21              0  ...           0                 Yes
# 23              0  ...           0                 Yes
# 25              0  ...           0                  No
# 26              0  ...           0                  No
# 29              0  ...           0                 Yes
# 32              0  ...           0                 Yes
# 33              0  ...           0                  No
# 35              0  ...           0                 Yes
# 37              0  ...           0                  No
# 41              0  ...           0                  No
# 43              0  ...           0                 Yes
# 45              0  ...           1                 Yes
# 51              0  ...           1                 Yes
# 61              0  ...           1                 Yes
# 62              0  ...           0                 Yes
# 68              0  ...           0                 Yes
# 70              0  ...           0                  No
# 72              0  ...           0                 Yes
# 74              0  ...           0                  No
# 78              0  ...           0                 Yes
# 79              0  ...           0                  No
# 81              0  ...           0                  No
# 82              0  ...           0                  No
# 84              0  ...           0                 Yes
# 85              0  ...           0                  No
# 90              0  ...           1                 Yes
# 92              0  ...           0                  No
# 94              0  ...           0                 Yes
# 95              0  ...           0                  No
# 97              0  ...           0                 Yes
# 102             0  ...           0                 Yes
# 105             0  ...           0                  No
# 106             0  ...           0                  No
# 110             0  ...           0                 Yes
# 111             0  ...           0                  No
# 113             0  ...           0                 Yes
# 118             0  ...           0                 Yes
# 119             0  ...           0                 Yes
# 120             0  ...           0                 Yes
# 121             0  ...           0                 Yes
# 134             0  ...           0                 Yes
# 140             0  ...           0                  No
# 151             0  ...           0                  No
# 153             0  ...           0                  No
# 164             0  ...           1                  No
#
#                                      Python Background  Statistics Courses  \
# 8    No programming background -- is Python Taylor ...                   1
# 10   Some Python -- I have had one class or written...                   4
# 16   No Python, but I've done some programming in o...                   1
# 17   Some Python -- I have had one class or written...                   0
# 18   No Python, but I've done some programming in o...                   1
# 21   No Python, but I've done some programming in o...                   1
# 23   No Python, but I've done some programming in o...                   0
# 25   No programming background -- is Python Taylor ...                   1
# 26   No programming background -- is Python Taylor ...                   0
# 29   Some Python -- I have had one class or written...                   0
# 32   Some Python -- I have had one class or written...                   1
# 33   No programming background -- is Python Taylor ...                   0
# 35   Some Python -- I have had one class or written...                   1
# 37   No programming background -- is Python Taylor ...                   1
# 41   No programming background -- is Python Taylor ...                   0
# 43   Some Python -- I have had one class or written...                   1
# 45   Some Python -- I have had one class or written...                   0
# 51   No Python, but I've done some programming in o...                   1
# 61   Some Python -- I have had one class or written...                   2
# 62   Some Python -- I have had one class or written...                   0
# 68   Some Python -- I have had one class or written...                   1
# 70   No programming background -- is Python Taylor ...                   1
# 72   Some Python -- I have had one class or written...                   1
# 74   No programming background -- is Python Taylor ...                   0
# 78   Some Python -- I have had one class or written...                   1
# 79   No programming background -- is Python Taylor ...                   0
# 81   No programming background -- is Python Taylor ...                   1
# 82   No programming background -- is Python Taylor ...                   1
# 84   No programming background -- is Python Taylor ...                   0
# 85   No programming background -- is Python Taylor ...                   1
# 90   Some Python -- I have had one class or written...                   0
# 92   Some Python -- I have had one class or written...                   1
# 94   Some Python -- I have had one class or written...                   1
# 95   No programming background -- is Python Taylor ...                   1
# 97   No Python, but I've done some programming in o...                   1
# 102  Some Python -- I have had one class or written...                   0
# 105  No programming background -- is Python Taylor ...                   0
# 106  No programming background -- is Python Taylor ...                   1
# 110  No Python, but I've done some programming in o...                   1
# 111  No programming background -- is Python Taylor ...                   0
# 113  No Python, but I've done some programming in o...                   0
# 118  No Python, but I've done some programming in o...                   1
# 119  Some Python -- I have had one class or written...                   0
# 120  Significant -- I am a wizard when it comes to ...                   1
# 121  No Python, but I've done some programming in o...                   0
# 134  Some Python -- I have had one class or written...                   0
# 140  No programming background -- is Python Taylor ...                   0
# 151  No programming background -- is Python Taylor ...                   0
# 153  No programming background -- is Python Taylor ...                   0
# 164  No programming background -- is Python Taylor ...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 8              4.0       1.0             7.0          5.0
# 10             3.0       0.0             6.0          6.0
# 16             6.0       2.0             7.0         12.0
# 17             4.0       0.0             7.0         10.0
# 18             7.0       0.0             7.0          7.0
# 21             2.0       2.0             7.0          NaN
# 23             4.0       1.0             6.0          4.0
# 25            10.0       0.0             7.0         10.0
# 26             2.0       2.0             7.0          4.0
# 29             2.5       NaN             7.5          5.0
# 32             4.0       0.0             7.0          3.0
# 33             1.0       3.0             7.0          3.0
# 35             3.0       0.0             7.0          4.0
# 37             2.0       3.0             7.0          5.0
# 41             2.0       2.0             6.0          3.0
# 43             2.0       2.0             8.0          2.0
# 45             3.0       1.0             8.5          3.0
# 51             9.0       0.0             7.0          6.0
# 61             3.0       3.0             8.0          5.0
# 62             3.0       0.0             8.0          4.0
# 68             3.0       1.0             7.0          4.0
# 70             3.0       1.0             7.0          5.0
# 72             3.0       1.0             8.0         15.0
# 74             5.0       4.0             6.0          7.0
# 78             2.0       1.0             8.0          3.0
# 79             6.0       1.0             5.0         25.0
# 81             4.0       2.0             6.0          5.0
# 82             3.0       0.0             8.0         17.0
# 84            10.0       0.0             7.0          6.0
# 85             2.0       3.0             7.0          8.0
# 90            10.0       0.0             7.5          2.0
# 92             3.0       1.0             6.0          5.0
# 94             3.0       0.0             6.0          5.0
# 95             4.0       2.0             7.0         12.0
# 97             5.0       1.0             7.0          5.0
# 102            4.0       1.0             7.0          4.0
# 105            4.0       1.0             7.0         20.0
# 106            6.0       0.0             6.0         10.0
# 110            3.0       1.0             8.0          6.0
# 111            4.0       1.0             8.0          4.0
# 113            0.5       1.0             6.0          3.0
# 118            0.5       1.0             7.0          7.0
# 119            3.0       0.0             9.0          3.0
# 120            5.0       1.0             7.0          5.0
# 121            0.0       0.0             9.0          5.0
# 134            3.0       1.0             7.0          2.0
# 140            2.0       2.0             8.0          9.0
# 151            2.0       1.0             7.0          5.0
# 153            6.0       0.0             7.0          3.0
# 164            1.0       1.0             7.0         12.0
#
#      People Texted Yesterday  Personality
# 8                        4.0     Ambivert
# 10                      15.0    Introvert
# 16                      50.0    Extrovert
# 17                      10.0     Ambivert
# 18                      19.0     Ambivert
# 21                      27.0     Ambivert
# 23                       6.0     Ambivert
# 25                     535.0     Ambivert
# 26                       5.0    Introvert
# 29                       2.0    Introvert
# 32                       6.0     Ambivert
# 33                      19.0     Ambivert
# 35                      30.0    Introvert
# 37                       9.0     Ambivert
# 41                       5.0     Ambivert
# 43                       2.0    Introvert
# 45                      20.0     Ambivert
# 51                       6.0     Ambivert
# 61                      10.0    Introvert
# 62                     300.0     Ambivert
# 68                       4.0    Introvert
# 70                       NaN     Ambivert
# 72                      10.0    Introvert
# 74                      10.0    Introvert
# 78                       1.0    Introvert
# 79                      15.0    Introvert
# 81                       6.0     Ambivert
# 82                       9.0     Ambivert
# 84                      13.0     Ambivert
# 85                       5.0     Ambivert
# 90                       8.0    Introvert
# 92                      13.0    Introvert
# 94                      15.0     Ambivert
# 95                      10.0    Introvert
# 97                      15.0     Ambivert
# 102                     10.0     Ambivert
# 105                    109.0    Extrovert
# 106                      9.0     Ambivert
# 110                     20.0     Ambivert
# 111                      6.0    Introvert
# 113                      3.0    Introvert
# 118                      7.0     Ambivert
# 119                     63.0     Ambivert
# 120                      7.0     Ambivert
# 121                     20.0    Extrovert
# 134                      6.0    Introvert
# 140                      4.0     Ambivert
# 151                      4.0     Ambivert
# 153                      8.0    Extrovert
# 164                     60.0    Introvert
#
# [50 rows x 31 columns]

# %% [markdown]
# Now, we are three weeks into the FALL 2019. With all the assignments piling up, our Freshmen friends are having a hard time catching up. Let's reduce their number of hours of sleep (by just 1 hour :) ) so that they don't look tired in Lincoln Hall Theatre (otherwise Wade and Karle will be worried).
#
# ### Question 2:
# Subtract 1 from "Hours of Sleep" for Freshmen and recalculate the new mean and new standard deviation (std). Notice which quantity changes and which does not on recalculation.

# %%
df_freshman["New Hrs Sleep"] = df_freshman["Hours of Sleep"] - 1
freshmen_sleep_new_mean = df_freshman["New Hrs Sleep"].mean()
freshmen_sleep_new_std = df_freshman["New Hrs Sleep"].std()
print(freshmen_sleep_new_mean)
print(freshmen_sleep_new_std)
# Out:
# 6.09
# 0.8124666398174919
# C:\Users\Dhruv Dahiya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(freshmen_sleep_mean == 7.09), "This does not appear correct."
assert(freshmen_sleep_std == 0.8124666398174921), "This does not appear correct ."
assert(freshmen_sleep_mean_new == 6.09), "This does not appear correct."
assert(freshmen_sleep_std_new == 0.8124666398174921),  "This does not appear correct."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-31debd85e7cc> in <module>
#       5
#       6 assert(freshmen_sleep_mean == 7.09), "This does not appear correct."
# ----> 7 assert(freshmen_sleep_std == 0.8124666398174921), "This does not appear correct ."
#       8 assert(freshmen_sleep_mean_new == 6.09), "This does not appear correct."
#       9 assert(freshmen_sleep_std_new == 0.8124666398174921),  "This does not appear correct."
#
# AssertionError: This does not appear correct .

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
